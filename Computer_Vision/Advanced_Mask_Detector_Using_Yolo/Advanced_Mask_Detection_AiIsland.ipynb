# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Wed Nov 25 00:54:25 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  00000.mp4
#  13050159104.mp4
#  1gZ6OlV9YFwETo3ZthSQCSRRf9qrbCnri.html
#  3466931377.pdf
#  3d.mp4
# 'Auto Call Recorder'
#  baba.mp4
# 'Birthday 2018 Full.mp4'
#  Classroom
# 'Colab Notebooks'
#  Communication
# 'Copie de decision_tree_classification.ipynb'
# 'Copie de decision_tree_regression.ipynb'
# 'Copie de kernel_svm.ipynb'
# 'Copie de k_nearest_neighbors.ipynb'
# 'Copie de logistic_regression.ipynb'
# 'Copie de multiple_linear_regression.ipynb'
# 'Copie de naive_bayes.ipynb'
# 'Copie de polynomial_regression.ipynb'
# 'Copie de random_forest_classification.ipynb'
# 'Copie de random_forest_regression.ipynb'
# 'Copie de support_vector_machine.ipynb'
# 'Copie de support_vector_regression.ipynb'
#  credit.mp4
# 'Data (1).gsheet'
# 'Devoire Libre zahraoui.gslides'
# 'Dossier sans titre'
#  DS2.rar
#  fbe05fa4-0722-48f6-81e3-78e63c9d1ea3.apk
# 'Fichier audio de Youssef Aljaoui'
# 'Hamza zahraoui.gdoc'
# 'Ims AO'
#  Machine-test
#  models
# ...

# %% [markdown]
# **1) Clone, configure & compile Darknet**

# %%
# Clone
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 14479 (delta 7), reused 13 (delta 7), pack-reused 14460
# Receiving objects: 100% (14479/14479), 13.22 MiB | 19.34 MiB/s, done.
# Resolving deltas: 100% (9842/9842), done.

# %%
# Configure
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# Compile
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %% [markdown]
# **2) Configure yolov3.cfg file**

# %%
# Make a copy of yolov3.cfg
# !cp /content/darknet/cfg/yolov3.cfg /content/darknet/cfg/yolov3_training.cfg

# %%
# Change lines in yolov3.cfg file
# !sed -i 's/batch=1/batch=40/' /content/darknet/cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' /content/darknet/cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' /content/darknet/cfg/yolov3_training.cfg
# !sed -i 1'610 s@classes=80@classes=2@' /content/darknet/cfg/yolov3_training.cfg
# !sed -i 1'696 s@classes=80@classes=2@' /content/darknet/cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=2@' /content/darknet/cfg/yolov3_training.cfg
# !sed -i 1'603 s@filters=255@filters=21@' /content/darknet/cfg/yolov3_training.cfg
# !sed -i '1689 s@filters=255@filters=21@' /content/darknet/cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=21@' /content/darknet/cfg/yolov3_training.cfg

# %% [markdown]
# **3) Create .names and .data files**

# %%
# !echo -e 'Wearing Mask\nNot Wearing Mask' > /content/darknet/data/obj.names
# !echo -e 'classes= 2\ntrain  = /content/darknet/data/train.txt\nvalid  = /content/darknet/data/test.txt\nnames = /content/darknet/data/obj.names\nbackup = /content/gdrive/Shareddrives/ALJAOUI/yolov3' > /content/darknet/data/obj.data

# %% [markdown]
# **4) Save yolov3_training.cfg and obj.names files in Google drive**

# %%
# !cp /content/darknet/cfg/yolov3_training.cfg  /content/gdrive/Shareddrives/ALJAOUI/yolov3/yolov3_testing.cfg
# !cp /content/darknet/data/obj.names  /content/gdrive/Shareddrives/ALJAOUI/yolov3/classes.txt

# %% [markdown]
# **5) Create a folder and unzip image dataset**

# %%
# !mkdir /content/darknet/data/obj
# !unzip /content/images1.zip -d /content/darknet/data/obj

# %% [markdown]
# **6) Create train.txt file**

# %%
import glob
images_list = glob.glob("/content/darknet/data/obj*.jpg")
with open("/content/darknet/data/train.txt", "w") as f:
    f.write("\n".join(images_list))

# %% [markdown]
# **7) Download pre-trained weights for the convolutional layers file**

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-11-25 01:34:36--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M   268KB/s    in 6m 39s
#
# 2020-11-25 01:41:17 (397 KB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# **8) Start training**

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Uncomment below and comment above to re-start your training from last saved weights
#!./darknet detector train /content/darknet/data/obj.data /content/darknet/cfg/yolov3_training.cfg /content/gdrive/Shareddrives/ALJAOUI/yolov3/yolov3_training_last.weights -dont_show
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 731.687073
#  total_bbox = 3806, rewritten_bbox = 0.052549 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.341085), count: 2, total_loss = 98.114685
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, total_loss = 275.537292
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, total_loss = 727.859314
#  total_bbox = 3808, rewritten_bbox = 0.052521 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.292888), count: 1, total_loss = 85.863235
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.442857), count: 2, total_loss = 295.864258
# ...
